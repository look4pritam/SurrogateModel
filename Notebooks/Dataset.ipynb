# %% [markdown]
# <a href="https://colab.research.google.com/github/look4pritam/SurrogateModel/blob/master/Notebooks/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset for Surrogate Model

# %% [markdown]
# ## Import Python packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Define design parameters.

# %%
n_samples = 1000
n_features = 5

# %% [markdown]
# ## Define bounds for each variable.

# %%
bounds = [
    (0, 10),
    (0, 5),
    (-3, 3),
    (1, 7),
    (0, 1)
]

# %% [markdown]
# ## Generate dataset.

# %%
def latin_hypercube_sampling(n_samples, n_features):
    rng = np.random.default_rng()
    result = np.zeros((n_samples, n_features))

    for i in range(n_features):
        perm = rng.permutation(n_samples)
        result[:, i] = (perm + rng.random(n_samples)) / n_samples

    return result

# Generate normalized samples (0–1)
lhs = latin_hypercube_sampling(n_samples, n_features)

# Scale to actual bounds
X = np.zeros_like(lhs)
for i in range(n_features):
    low, high = bounds[i]
    X[:, i] = low + (high - low) * lhs[:, i]

# %% [markdown]
# ## Define target function.

# %%
def target_function(X):
    x1, x2, x3, x4, x5 = X.T

    y = (
        np.sin(x1) +
        np.log(x2 + 1) +
        x3**2 +
        np.sqrt(x4) +
        np.exp(x5)
    )

    return y

y = target_function(X)

# %% [markdown]
# ## Create data frame.

# %%
columns = [f"x{i+1}" for i in range(n_features)]
df = pd.DataFrame(X, columns=columns)
df["y"] = y

# %% [markdown]
# ## Save dataset.

# %%
df.to_csv("dataset.csv", index=False)

# %% [markdown]
# ## Show sample dataset.

# %%
print("Dataset generated")
print(df.head())
# Out:
# Dataset generated
#          x1        x2        x3        x4        x5         y
# 0  5.693782  0.269749 -2.384986  4.830284  0.013856  8.582853
# 1  8.229585  2.437212  0.226618  1.573730  0.132740  4.612740
# 2  4.295100  2.884030  1.805446  3.311133  0.408559  7.026617
# 3  9.848426  4.795096 -2.008080  2.244645  0.123317  8.007767
# 4  4.953071  1.513938  0.992698  6.441931  0.506979  5.134488
