# %% [markdown]
# <a href="https://colab.research.google.com/github/look4pritam/SurrogateModel/blob/master/Notebooks/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset for Surrogate Model

# %% [markdown]
# ## Import Python packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Define design parameters.

# %%
n_samples = 1000
n_features = 5

# %% [markdown]
# ## Define bounds for each variable.

# %%
bounds = [
    (0, 10),
    (0, 5),
    (-3, 3),
    (1, 7),
    (0, 1)
]

# %% [markdown]
# ## Generate dataset.

# %%
def latin_hypercube_sampling(n_samples, n_features):
    rng = np.random.default_rng()
    result = np.zeros((n_samples, n_features))

    for i in range(n_features):
        perm = rng.permutation(n_samples)
        result[:, i] = (perm + rng.random(n_samples)) / n_samples

    return result

# Generate normalized samples (0–1)
lhs = latin_hypercube_sampling(n_samples, n_features)

# Scale to actual bounds
X = np.zeros_like(lhs)
for i in range(n_features):
    low, high = bounds[i]
    X[:, i] = low + (high - low) * lhs[:, i]

# %% [markdown]
# ## Define target function.

# %%
def target_function(X):
    x1, x2, x3, x4, x5 = X.T

    y = (
        np.sin(x1) +
        np.log(x2 + 1) +
        x3**2 +
        np.sqrt(x4) +
        np.exp(x5)
    )

    return y

y = target_function(X)

# %% [markdown]
# ## Create data frame.

# %%
columns = [f"x{i+1}" for i in range(n_features)]
df = pd.DataFrame(X, columns=columns)
df["y"] = y

# %% [markdown]
# ## Save dataset.

# %%
df.to_csv("dataset.csv", index=False)

# %% [markdown]
# ## Show sample dataset.

# %%
print("Dataset generated")
print(df.head())
# Out:
# Dataset generated
#          x1        x2        x3        x4        x5          y
# 0  1.838020  4.619036 -2.330672  2.368227  0.883207  12.080247
# 1  1.912993  3.919004  2.333990  3.693733  0.072702  10.979953
# 2  2.418836  0.153366 -0.736638  1.588796  0.385574   4.077707
# 3  6.693689  2.011012 -1.724972  1.730190  0.775440   7.963788
# 4  3.448421  0.170704 -1.816439  5.716867  0.834110   7.848781
